# %% [markdown]
# # Bibliotecas fundamentais para Ciência de Dados

# %% [markdown]
# ## 1 - Pandas

# %% [markdown]
#  <img src="https://storage.googleapis.com/lds-media/images/the-rise-in-popularity-of-pandas.width-1200.png" />

# %% [markdown]
#  <img src="https://storage.googleapis.com/lds-media/images/series-and-dataframe.width-1200.png" />

# %% [markdown]
# Lendo um arquivo csv:

# %%
import pandas as pd # bibliote Pandas é usada para manipulação de dados

data = pd.read_csv('data/iris.csv', header=(0), encoding = "ISO-8859-1")
print("Número de linhas e colunas:",data.shape)
data.head(10)
# Out:
# Número de linhas e colunas: (150, 5)
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 6           4.6          3.4           1.4          0.3  setosa
# 7           5.0          3.4           1.5          0.2  setosa
# 8           4.4          2.9           1.4          0.2  setosa
# 9           4.9          3.1           1.5          0.1  setosa

# %% [markdown]
# Podemos ainda visualizar o final da tabela:

# %%
data.tail(10)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 140           6.7          3.1           5.6          2.4  virginica
# 141           6.9          3.1           5.1          2.3  virginica
# 142           5.8          2.7           5.1          1.9  virginica
# 143           6.8          3.2           5.9          2.3  virginica
# 144           6.7          3.3           5.7          2.5  virginica
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %% [markdown]
# Acessando algunas linhas:

# %%
# Look at the first 3 rows
data[:5]
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# Acessando colunas:

# %%
data['sepal_length']
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepal_length, Length: 150, dtype: float64

# %% [markdown]
# Graficando uma coluna:

# %%
data['sepal_width'].plot(figsize=(10, 5))
# Out:
# <AxesSubplot:>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
data.shape
# Out:
# (150, 5)

# %% [markdown]
# Removendo dados duplicados:

# %%
data = data.drop_duplicates()
data.shape
# Out:
# (147, 5)

# %% [markdown]
# Podemos renomear o nome dos atributos:

# %%
print(data.columns)
data.head()
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
data.rename(columns={
        'sepal_length': 'Comprimento da Sepala', 
        'sepal_width': 'Largura da Sepala'
    }, inplace=True)
print(data.columns)
data.head()
# Out:
# Index(['Comprimento da Sepala', 'Largura da Sepala', 'petal_length',
#        'petal_width', 'species'],
#       dtype='object')
#    Comprimento da Sepala  Largura da Sepala  petal_length  petal_width species
# 0                    5.1                3.5           1.4          0.2  setosa
# 1                    4.9                3.0           1.4          0.2  setosa
# 2                    4.7                3.2           1.3          0.2  setosa
# 3                    4.6                3.1           1.5          0.2  setosa
# 4                    5.0                3.6           1.4          0.2  setosa

# %% [markdown]
# Ou ainda, podemos usar:

# %%
data.columns = ['Comp-Sepala','Largura-Sepala','Comp-petala','Largura-petala','Specie']
data.head()
# Out:
#    Comp-Sepala  Largura-Sepala  Comp-petala  Largura-petala  Specie
# 0          5.1             3.5          1.4             0.2  setosa
# 1          4.9             3.0          1.4             0.2  setosa
# 2          4.7             3.2          1.3             0.2  setosa
# 3          4.6             3.1          1.5             0.2  setosa
# 4          5.0             3.6          1.4             0.2  setosa

# %% [markdown]
# Podemos colocar o nome das colunas e minúsculo:

# %%
data.columns = [col.lower() for col in data]
data.head()
# Out:
#    comp-sepala  largura-sepala  comp-petala  largura-petala  specie
# 0          5.1             3.5          1.4             0.2  setosa
# 1          4.9             3.0          1.4             0.2  setosa
# 2          4.7             3.2          1.3             0.2  setosa
# 3          4.6             3.1          1.5             0.2  setosa
# 4          5.0             3.6          1.4             0.2  setosa

# %% [markdown]
# Podemos ainda ler de uma url:

# %%
import pandas as pd

url="https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv"
data=pd.read_csv(url)
data.head(10)
# Out:
#                     Country  Region
# 0                   Algeria  AFRICA
# 1                    Angola  AFRICA
# 2                     Benin  AFRICA
# 3                  Botswana  AFRICA
# 4                   Burkina  AFRICA
# 5                   Burundi  AFRICA
# 6                  Cameroon  AFRICA
# 7                Cape Verde  AFRICA
# 8  Central African Republic  AFRICA
# 9                      Chad  AFRICA

# %% [markdown]
# Mais um exemplo:

# %%
import pandas as pd

url="https://www1.ncdc.noaa.gov/pub/data/cdo/samples/PRECIP_HLY_sample_csv.csv"
data=pd.read_csv(url)
data.head(10)
# Out:
#        STATION     STATION_NAME  ELEVATION  LATITUDE  LONGITUDE  \
# 0  COOP:310301  ASHEVILLE NC US      682.1   35.5954   -82.5568
# 1  COOP:310301  ASHEVILLE NC US      682.1   35.5954   -82.5568
# 2  COOP:310301  ASHEVILLE NC US      682.1   35.5954   -82.5568
#
#              DATE   HPCP Measurement Flag Quality Flag
# 0  20100101 00:00  99999                ]
# 1  20100101 01:00      0                g
# 2  20100102 06:00      1

# %% [markdown]
# Criando um dataframe:

# %%
data = {
    'apples': [3, 2, 0, 1], 
    'oranges': [0, 3, 7, 2]
}
purchases = pd.DataFrame(data)
purchases.head()
# Out:
#    apples  oranges
# 0       3        0
# 1       2        3
# 2       0        7
# 3       1        2

# %%
import numpy as np
x1 = ['A','B','B','B','B','A','B','C','B','A']
x2 = np.random.normal(0,1,10)
x3 = np.random.normal(0,1,10)
data = {
    'X1': x1, 
    'X2': x2,
    'X3': x3
}
purchases = pd.DataFrame(data)
purchases.head(10)
# Out:
#   X1        X2        X3
# 0  A  1.254392  0.865824
# 1  B -1.435259  0.437074
# 2  B  0.875046  0.582864
# 3  B  0.855927 -0.241727
# 4  B  0.891628  0.253111
# 5  A  1.735052  0.194334
# 6  B  0.967370  1.946114
# 7  C  0.754367  0.518601
# 8  B -0.357760 -1.502131
# 9  A -1.119545  1.207894

# %%
data = {
    'apples': [3, 2, 0, 1, 0], 
    'oranges': [0, 3, 7, 2, 5]
}
purchases = pd.DataFrame(data, index=['Maria', 'Luis', 'Carlos', 'Ana', 'Maria'])
purchases.head()
# Out:
#         apples  oranges
# Maria        3        0
# Luis         2        3
# Carlos       0        7
# Ana          1        2
# Maria        0        5

# %% [markdown]
# Para localizar um usuário:

# %%
purchases.loc['Maria']
# Out:
#        apples  oranges
# Maria       3        0
# Maria       0        5

# %% [markdown]
# Salvando em um arquivo:

# %%
purchases.to_csv('new_purchases.csv')

# %% [markdown]
# Identificando valores nulos:

# %%
import pandas as pd

url="https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv"
data=pd.read_csv(url)
data.head(10)
data.isnull().sum()
# Out:
# Country    0
# Region     0
# dtype: int64

# %%
data.dropna(axis=1)
# Out:
#        Country         Region
# 0      Algeria         AFRICA
# 1       Angola         AFRICA
# 2        Benin         AFRICA
# 3     Botswana         AFRICA
# 4      Burkina         AFRICA
# ..         ...            ...
# 189   Paraguay  SOUTH AMERICA
# 190       Peru  SOUTH AMERICA
# 191   Suriname  SOUTH AMERICA
# 192    Uruguay  SOUTH AMERICA
# 193  Venezuela  SOUTH AMERICA
#
# [194 rows x 2 columns]

# %%
country = data['Region']
country.head(10)
# Out:
# 0    AFRICA
# 1    AFRICA
# 2    AFRICA
# 3    AFRICA
# 4    AFRICA
# 5    AFRICA
# 6    AFRICA
# 7    AFRICA
# 8    AFRICA
# 9    AFRICA
# Name: Region, dtype: object

# %%
import pandas as pd # bibliote Pandas é usada para manipulação de dados

data = pd.read_csv('data/winequality-red.csv', header=(0), encoding = "ISO-8859-1")
print("Número de linhas e colunas:",data.shape)
data.head(10)
# Out:
# Número de linhas e colunas: (1599, 12)
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6      0.069
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
table = data.describe()
data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
table = data.describe()
print('Media:', table['fixed acidity'][1])
# Out:
# Media: 8.319637273295838

# %%
data['fixed acidity'].describe()
# Out:
# count    1599.000000
# mean        8.319637
# std         1.741096
# min         4.600000
# 25%         7.100000
# 50%         7.900000
# 75%         9.200000
# max        15.900000
# Name: fixed acidity, dtype: float64

# %%
data['quality'].value_counts().head(10)
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %%
table_corr = data.corr()
data.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
table_corr[:2]
# Out:
#                   fixed acidity  volatile acidity  citric acid  \
# fixed acidity          1.000000         -0.256131     0.671703
# volatile acidity      -0.256131          1.000000    -0.552496
#
#                   residual sugar  chlorides  free sulfur dioxide  \
# fixed acidity           0.114777   0.093705            -0.153794
# volatile acidity        0.001918   0.061298            -0.010504
#
#                   total sulfur dioxide   density        pH  sulphates  \
# fixed acidity                -0.113181  0.668047 -0.682978   0.183006
# volatile acidity              0.076470  0.022026  0.234937  -0.260987
#
#                    alcohol   quality
# fixed acidity    -0.061668  0.124052
# volatile acidity -0.202288 -0.390558

# %% [markdown]
# Selecionando partes dos dados por colunas:

# %%
density = data['density']
type(density)
# Out:
# pandas.core.series.Series

# %%
density = data[['density']]
type(density)
# Out:
# pandas.core.frame.DataFrame

# %%
subset = data[['fixed acidity', 'chlorides','pH']]

subset.head(10)
# Out:
#    fixed acidity  chlorides    pH
# 0            7.4      0.076  3.51
# 1            7.8      0.098  3.20
# 2            7.8      0.092  3.26
# 3           11.2      0.075  3.16
# 4            7.4      0.076  3.51
# 5            7.4      0.075  3.51
# 6            7.9      0.069  3.30
# 7            7.3      0.065  3.39
# 8            7.8      0.073  3.36
# 9            7.5      0.071  3.35

# %% [markdown]
# Selecionando partes dos dados por linhas:

# %%
sel_rows = data.iloc[2]
print(sel_rows)
# Out:
# fixed acidity            7.800
# volatile acidity         0.760
# citric acid              0.040
# residual sugar           2.300
# chlorides                0.092
# free sulfur dioxide     15.000
# total sulfur dioxide    54.000
# density                  0.997
# pH                       3.260
# sulphates                0.650
# alcohol                  9.800
# quality                  5.000
# Name: 2, dtype: float64

# %%
sel_rows = data.iloc[2:5]
print(sel_rows)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
condition = (data['quality'] == 5)
condition.head(10)
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4     True
# 5     True
# 6     True
# 7    False
# 8    False
# 9     True
# Name: quality, dtype: bool

# %%
data[data['quality'] == 3]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 459            11.6             0.580         0.66            2.20      0.074
# 517            10.4             0.610         0.49            2.10      0.200
# 690             7.4             1.185         0.00            4.25      0.097
# 832            10.4             0.440         0.42            1.50      0.145
# 899             8.3             1.020         0.02            3.40      0.084
# 1299            7.6             1.580         0.00            2.10      0.137
# 1374            6.8             0.815         0.00            1.20      0.267
# 1469            7.3             0.980         0.05            2.10      0.061
# 1478            7.1             0.875         0.05            5.70      0.082
# 1505            6.7             0.760         0.02            1.80      0.078
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
data[data['residual sugar'] >= 6].head(10)
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 9              7.5             0.500         0.36             6.1      0.071
# 11             7.5             0.500         0.36             6.1      0.071
# 33             6.9             0.605         0.12            10.7      0.073
# 163            7.4             0.600         0.26             7.3      0.070
# 164            7.3             0.590         0.26             7.2      0.070
# 274            7.5             0.650         0.18             7.0      0.088
# 278           10.3             0.320         0.45             6.4      0.073
# 324           10.0             0.490         0.20            11.0      0.071
# 325           10.0             0.490         0.20            11.0      0.071
# 378           11.4             0.625         0.66             6.2      0.088
#
#      free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
data[(data['fixed acidity'] == 7.8) | (data['volatile acidity'] == 0.5)].head(10)
# Out:
#     fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1             7.8             0.880         0.00             2.6      0.098
# 2             7.8             0.760         0.04             2.3      0.092
# 8             7.8             0.580         0.02             2.0      0.073
# 9             7.5             0.500         0.36             6.1      0.071
# 11            7.5             0.500         0.36             6.1      0.071
# 13            7.8             0.610         0.29             1.6      0.114
# 29            7.8             0.645         0.00             2.0      0.082
# 35            7.8             0.645         0.00             5.5      0.086
# 36            7.8             0.600         0.14             2.4      0.086
# 52            6.6             0.500         0.04             2.1      0.068
#
#     free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
data[
    ((data['fixed acidity'] >= 7.8) & (data['volatile acidity'] <= 0.5))
    & (data['citric acid'] > 0.5)
]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 3              11.2              0.28         0.56             1.9      0.075
# 16              8.5              0.28         0.56             1.8      0.092
# 19              7.9              0.32         0.51             1.8      0.341
# 47              8.7              0.29         0.52             1.6      0.113
# 56             10.2              0.42         0.57             3.4      0.070
# ...             ...               ...          ...             ...        ...
# 1416           10.0              0.32         0.59             2.2      0.077
# 1454           11.7              0.45         0.63             2.2      0.073
# 1479            8.2              0.28         0.60             3.0      0.104
# 1481            8.2              0.28         0.60             3.0      0.104
# 1576            8.0              0.30         0.63             1.6      0.081
#
# ...

# %%
data.head(20)
# Out:
#     fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             7.4             0.700         0.00             1.9      0.076
# 1             7.8             0.880         0.00             2.6      0.098
# 2             7.8             0.760         0.04             2.3      0.092
# 3            11.2             0.280         0.56             1.9      0.075
# 4             7.4             0.700         0.00             1.9      0.076
# 5             7.4             0.660         0.00             1.8      0.075
# 6             7.9             0.600         0.06             1.6      0.069
# 7             7.3             0.650         0.00             1.2      0.065
# 8             7.8             0.580         0.02             2.0      0.073
# 9             7.5             0.500         0.36             6.1      0.071
# 10            6.7             0.580         0.08             1.8      0.097
# ...

# %% [markdown]
# Aplicando uma função ao dados:

# %%
def quality(x):
    if x >= 6.0:
        return "good"
    else:
        return "bad"

data_quali = data["quality"].apply(quality)

data_quali.head(10)
# Out:
# 0     bad
# 1     bad
# 2     bad
# 3    good
# 4     bad
# 5     bad
# 6     bad
# 7    good
# 8    good
# 9     bad
# Name: quality, dtype: object

# %%
data.plot(kind='scatter', x='fixed acidity', y='volatile acidity', title='Acidity');

# %%
data['quality'].plot(kind='hist', title='Quality');

# %%
data['fixed acidity'].plot(kind="box");

# %%
data.boxplot(column='fixed acidity', by='quality', figsize=(10, 5));

# %% [markdown]
# Leitura adicional: https://www.learndatasci.com/tutorials/python-pandas-tutorial-complete-introduction-for-beginners/

# %% [markdown]
# ## 2 - Scipy

# %% [markdown]
# https://nbviewer.jupyter.org/github/jrjohansson/scientific-python-lectures/blob/master/Lecture-3-Scipy.ipynb

# %% [markdown]
# ## 3 - Numpy

# %% [markdown]
# https://cs231n.github.io/python-numpy-tutorial/

# %% [markdown]
# ## 4 - Matplotlib

# %%
import numpy as np
import matplotlib.pyplot as plt

# Compute the x and y coordinates for points on a sine curve
x = np.arange(0, 3 * np.pi, 0.1)
y = np.sin(x)

# Plot the points using matplotlib
plt.figure(figsize=(8, 4))
plt.plot(x, y)
plt.show()  # You must call plt.show() to make graphics appear.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Compute the x and y coordinates for points on sine and cosine curves
x = np.arange(0, 3 * np.pi, 0.1)
y_sin = np.sin(x)
y_cos = np.cos(x)

# Plot the points using matplotlib
plt.figure(figsize=(8, 4))
plt.plot(x, y_sin, label = 'Sine')
plt.plot(x, y_cos, label = 'Cosine')
plt.xlabel('x axis label')
plt.ylabel('y axis label')
plt.title('Sine and Cosine')
plt.legend()
plt.show()

# %%
import numpy as np
x = np.linspace(0, 10, 100)

fig = plt.figure()
plt.plot(x, np.sin(x), '-')
plt.plot(x, np.cos(x), '--');

# %%
fig.savefig("filename.pdf")

# %%
import numpy as np
import matplotlib.pyplot as plt

# Compute the x and y coordinates for points on sine and cosine curves
x = np.arange(0, 3 * np.pi, 0.1)
y_sin = np.sin(x)
y_cos = np.cos(x)

# Set up a subplot grid that has height 2 and width 1,
# and set the first such subplot as active.
plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)

# Make the first plot
plt.plot(x, y_sin)
plt.title('Sine')

# Set the second subplot as active, and make the second plot.
plt.subplot(2, 1, 2)
plt.plot(x, y_cos)
plt.title('Cosine')

# Show the figure.
plt.show()

# %%
x = np.linspace(0, 5, 10)
y = x ** 2

fig = plt.figure()

axes = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # left, bottom, width, height (range 0 to 1)

axes.plot(x, y, 'r')

axes.set_xlabel('x')
axes.set_ylabel('y')
axes.set_title('title');

fig = plt.figure()
axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # main axes
axes2 = fig.add_axes([0.2, 0.5, 0.4, 0.3]) # inset axes

# main figure
axes1.plot(x, y, 'r')
axes1.set_xlabel('x')
axes1.set_ylabel('y')
axes1.set_title('title')

# insert
axes2.plot(y, x, 'g')
axes2.set_xlabel('y')
axes2.set_ylabel('x')
axes2.set_title('insert title');

# %%
import matplotlib.pyplot as plt
image = plt.imread('cat.png')
plt.imshow(image)

# %%
import cv2
image= cv2.imread('cat.png')
cv2.imshow('image', image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
n = 1000
X = np.random.normal(0,1,n)
Y = np.random.normal(0,1,n)
plt.xlabel("x", fontsize=20)
plt.ylabel("Y", fontsize=20)
plt.scatter(X,Y)
plt.show(True)

# %%
n = 12
X = np.arange(n)
Y1 = (1 - X / float(n)) * np.random.uniform(0.5, 1.0, n)
Y2 = (1 - X / float(n)) * np.random.uniform(0.5, 1.0, n)
plt.bar(X, +Y1, facecolor='#9999ff', edgecolor='white')
plt.bar(X, -Y2, facecolor='#ff9999', edgecolor='white')
for x, y in zip(X, Y1): #Mostra os valores
    plt.text(x + 0.4, y + 0.05, '%.2f' % y, ha='center', va= 'bottom')
plt.ylim(-1.25, +1.25)
plt.show(True)

# %%
def f(x, y):
    return (1 - x / 2 + x ** 5 + y ** 3) * np.exp(-x ** 2 -y ** 2)
n = 256
x = np.linspace(-3, 3, n)
y = np.linspace(-3, 3, n)
X, Y = np.meshgrid(x, y)
plt.contourf(X, Y, f(X, Y), 8, alpha=.75, cmap='jet')
plt.contour(X, Y, f(X, Y), 8, colors='black')
plt.show(True)

# %%
Z = np.random.uniform(0, 1, 20)
plt.pie(Z)
plt.show(True)

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = Axes3D(fig)
X = np.arange(-4, 4, 0.25)
Y = np.arange(-4, 4, 0.25)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)
ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap='hot')
plt.show(True)

# %%
data = np.random.randn(100)
plt.hist(data);
plt.show(True)

# %%
x = [21,22,23,4,5,6,77,8,9,10,31,32,33,34,35,36,37,18,49,50,100]
num_bins = 10
n, bins, patches = plt.hist(x, num_bins, facecolor='blue', alpha=0.5)
plt.show()

# %%
n, bins, patches = plt.hist(x, bins='auto', facecolor='blue', alpha=0.5)
plt.show()

# %%
x1 = np.random.normal(0, 0.8, 1000) #mu = 0, sigma = 0.8
x2 = np.random.normal(-2, 1, 1000)
x3 = np.random.normal(3, 2, 1000)

kwargs = dict(histtype='stepfilled', alpha=0.5, density=True, bins=40)

plt.hist(x1, **kwargs)
plt.hist(x2, **kwargs)
plt.hist(x3, **kwargs)

plt.show(True)
